# %% [markdown]
# <a href="https://colab.research.google.com/github/SangeethaShaji/LGM-DataScience/blob/main/TasK2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Lets Grow More**
#
# **Task:2**
#
# **Name: Sangeetha Shaji**
#
# **Data Science Internship**
#
# **Image to Pencil Sketch with Python**
#
# **Description Of Task**: We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.
#
#
# **Importing Libraries**

# %%
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# **Read the Image**

# %%
img1 = cv2.imread("elsa.jpg")
plt.figure(figsize=(8,8))
plt.imshow(img1)
plt.show()

# %% [markdown]
# **Converting the image to rgb color**

# %%
rgbimage1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,8))
plt.imshow(rgbimage1)
plt.show()

# %% [markdown]
# **Converting the rgb image into a gray scale image**

# %%
grayimage1=cv2.cvtColor(rgbimage1,cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(8,8))
plt.imshow(grayimage1,cmap='gray')
plt.show()

# %% [markdown]
# **Converting the gray scale image into a inverted image**

# %%
invtgrayimage1=255 - grayimage1
plt.figure(figsize=(8,8))
plt.imshow(invtgrayimage1,cmap='gray')
plt.show()

# %% [markdown]
# **Bluring the inverted grayscale image using Gausssian Blur**

# %%
blurimage1=cv2.GaussianBlur(invtgrayimage1,(21,21),0)
plt.figure(figsize=(8,8))
plt.imshow(blurimage1,cmap='gray')
plt.show()

# %% [markdown]
# **Now inverting the blurred image**

# %%
invtgrayimage1=255-blurimage1
plt.figure(figsize=(8,8))
plt.imshow(invtgrayimage1,cmap='gray')
plt.show()

# %% [markdown]
# **Now for the final touch divide the grayscale image with inverted blurred image**

# %%
sketch1=cv2.divide(grayimage1,invtgrayimage1,scale=256.0)
plt.figure(figsize=(8,8))
plt.imshow(rgbimage1)
plt.figure(figsize=(8,8))
plt.imshow(sketch1,cmap='gray')
plt.show()
